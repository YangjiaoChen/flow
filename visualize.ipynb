# %%
# Install a pip package in the current Jupyter kernel
import sys
# !{sys.executable} -m pip install tensorflow
import tensorflow as tf
# Out:
# Collecting tensorflow
#   Downloading tensorflow-2.12.0-cp38-cp38-macosx_10_15_x86_64.whl (230.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 230.1/230.1 MB 2.2 MB/s eta 0:00:0000:0100:01
# Collecting google-pasta>=0.1.1
#   Using cached google_pasta-0.2.0-py3-none-any.whl (57 kB)
# Collecting absl-py>=1.0.0
#   Using cached absl_py-1.4.0-py3-none-any.whl (126 kB)
# Requirement already satisfied: wrapt<1.15,>=1.11.0 in /Users/yangjiaochen/anaconda3/lib/python3.8/site-packages (from tensorflow) (1.14.1)
# Requirement already satisfied: packaging in /Users/yangjiaochen/anaconda3/lib/python3.8/site-packages (from tensorflow) (23.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /Users/yangjiaochen/anaconda3/lib/python3.8/site-packages (from tensorflow) (4.4.0)
# Collecting keras<2.13,>=2.12.0
#   Downloading keras-2.12.0-py2.py3-none-any.whl (1.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 19.5 MB/s eta 0:00:00a 0:00:01
# Collecting tensorflow-io-gcs-filesystem>=0.23.1
#   Downloading tensorflow_io_gcs_filesystem-0.32.0-cp38-cp38-macosx_10_14_x86_64.whl (1.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 20.1 MB/s eta 0:00:0000:0100:01
# Collecting libclang>=13.0.0
#   Downloading libclang-16.0.0-py2.py3-none-macosx_10_9_x86_64.whl (26.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 26.7/26.7 MB 16.9 MB/s eta 0:00:0000:0100:01
# Collecting flatbuffers>=2.0
#   Using cached flatbuffers-23.3.3-py2.py3-none-any.whl (26 kB)
# Collecting opt-einsum>=2.3.2
#   Using cached opt_einsum-3.3.0-py3-none-any.whl (65 kB)
# Requirement already satisfied: h5py>=2.9.0 in /Users/yangjiaochen/anaconda3/lib/python3.8/site-packages (from tensorflow) (3.7.0)
# Collecting gast<=0.4.0,>=0.2.1
#   Using cached gast-0.4.0-py3-none-any.whl (9.8 kB)
# Collecting tensorboard<2.13,>=2.12
#   Downloading tensorboard-2.12.2-py3-none-any.whl (5.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.6/5.6 MB 18.0 MB/s eta 0:00:0000:0100:01
# Collecting grpcio<2.0,>=1.24.3
#   Downloading grpcio-1.54.0-cp38-cp38-macosx_10_10_universal2.whl (8.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.7/8.7 MB 17.9 MB/s eta 0:00:0000:0100:01
# Requirement already satisfied: six>=1.12.0 in /Users/yangjiaochen/anaconda3/lib/python3.8/site-packages (from tensorflow) (1.16.0)
# Collecting astunparse>=1.6.0
#   Using cached astunparse-1.6.3-py2.py3-none-any.whl (12 kB)
# Collecting jax>=0.3.15
#   Downloading jax-0.4.8.tar.gz (1.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 17.3 MB/s eta 0:00:00a 0:00:01
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting termcolor>=1.1.0
#   Using cached termcolor-2.3.0-py3-none-any.whl (6.9 kB)
# Collecting tensorflow-estimator<2.13,>=2.12.0
#   Downloading tensorflow_estimator-2.12.0-py2.py3-none-any.whl (440 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 440.7/440.7 kB 8.8 MB/s eta 0:00:0000:01
# Requirement already satisfied: numpy<1.24,>=1.22 in /Users/yangjiaochen/anaconda3/lib/python3.8/site-packages (from tensorflow) (1.23.5)
# Requirement already satisfied: setuptools in /Users/yangjiaochen/anaconda3/lib/python3.8/site-packages (from tensorflow) (65.6.3)
# Collecting protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3
#   Using cached protobuf-4.22.3-cp37-abi3-macosx_10_9_universal2.whl (397 kB)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /Users/yangjiaochen/anaconda3/lib/python3.8/site-packages (from astunparse>=1.6.0->tensorflow) (0.38.4)
# Requirement already satisfied: scipy>=1.7 in /Users/yangjiaochen/anaconda3/lib/python3.8/site-packages (from jax>=0.3.15->tensorflow) (1.7.3)
# Collecting ml-dtypes>=0.0.3
#   Downloading ml_dtypes-0.1.0-cp38-cp38-macosx_10_9_universal2.whl (317 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 317.8/317.8 kB 14.3 MB/s eta 0:00:00
# Collecting google-auth<3,>=1.6.3
#   Downloading google_auth-2.17.3-py2.py3-none-any.whl (178 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 178.2/178.2 kB 16.8 MB/s eta 0:00:00
# Requirement already satisfied: markdown>=2.6.8 in /Users/yangjiaochen/anaconda3/lib/python3.8/site-packages (from tensorboard<2.13,>=2.12->tensorflow) (3.4.1)
# Collecting tensorboard-plugin-wit>=1.6.0
#   Downloading tensorboard_plugin_wit-1.8.1-py3-none-any.whl (781 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 781.3/781.3 kB 19.3 MB/s eta 0:00:0000:01
# Collecting google-auth-oauthlib<1.1,>=0.5
#   Downloading google_auth_oauthlib-1.0.0-py2.py3-none-any.whl (18 kB)
# Requirement already satisfied: requests<3,>=2.21.0 in /Users/yangjiaochen/anaconda3/lib/python3.8/site-packages (from tensorboard<2.13,>=2.12->tensorflow) (2.28.1)
# Requirement already satisfied: werkzeug>=1.0.1 in /Users/yangjiaochen/anaconda3/lib/python3.8/site-packages (from tensorboard<2.13,>=2.12->tensorflow) (2.2.3)
# Collecting tensorboard-data-server<0.8.0,>=0.7.0
#   Downloading tensorboard_data_server-0.7.0-py3-none-macosx_10_9_x86_64.whl (4.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.8/4.8 MB 17.0 MB/s eta 0:00:0000:0100:01
# Collecting rsa<5,>=3.1.4
#   Downloading rsa-4.9-py3-none-any.whl (34 kB)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /Users/yangjiaochen/anaconda3/lib/python3.8/site-packages (from google-auth<3,>=1.6.3->tensorboard<2.13,>=2.12->tensorflow) (0.2.8)
# Collecting cachetools<6.0,>=2.0.0
#   Downloading cachetools-5.3.0-py3-none-any.whl (9.3 kB)
# Collecting requests-oauthlib>=0.7.0
#   Downloading requests_oauthlib-1.3.1-py2.py3-none-any.whl (23 kB)
# Requirement already satisfied: importlib-metadata>=4.4 in /Users/yangjiaochen/anaconda3/lib/python3.8/site-packages (from markdown>=2.6.8->tensorboard<2.13,>=2.12->tensorflow) (6.0.0)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/yangjiaochen/anaconda3/lib/python3.8/site-packages (from requests<3,>=2.21.0->tensorboard<2.13,>=2.12->tensorflow) (2022.12.7)
# Requirement already satisfied: charset-normalizer<3,>=2 in /Users/yangjiaochen/anaconda3/lib/python3.8/site-packages (from requests<3,>=2.21.0->tensorboard<2.13,>=2.12->tensorflow) (2.0.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /Users/yangjiaochen/anaconda3/lib/python3.8/site-packages (from requests<3,>=2.21.0->tensorboard<2.13,>=2.12->tensorflow) (1.26.15)
# Requirement already satisfied: idna<4,>=2.5 in /Users/yangjiaochen/anaconda3/lib/python3.8/site-packages (from requests<3,>=2.21.0->tensorboard<2.13,>=2.12->tensorflow) (3.4)
# Collecting numpy<1.24,>=1.22
#   Downloading numpy-1.22.4-cp38-cp38-macosx_10_15_x86_64.whl (17.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.6/17.6 MB 14.5 MB/s eta 0:00:0000:0100:01
# Requirement already satisfied: MarkupSafe>=2.1.1 in /Users/yangjiaochen/anaconda3/lib/python3.8/site-packages (from werkzeug>=1.0.1->tensorboard<2.13,>=2.12->tensorflow) (2.1.1)
# Requirement already satisfied: zipp>=0.5 in /Users/yangjiaochen/anaconda3/lib/python3.8/site-packages (from importlib-metadata>=4.4->markdown>=2.6.8->tensorboard<2.13,>=2.12->tensorflow) (3.11.0)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /Users/yangjiaochen/anaconda3/lib/python3.8/site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.13,>=2.12->tensorflow) (0.4.8)
# Collecting oauthlib>=3.0.0
#   Downloading oauthlib-3.2.2-py3-none-any.whl (151 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 151.7/151.7 kB 10.6 MB/s eta 0:00:00
# Building wheels for collected packages: jax
#   Building wheel for jax (pyproject.toml) ... done
#   Created wheel for jax: filename=jax-0.4.8-py3-none-any.whl size=1439678 sha256=f03268976874f708ad03d17402b2b8f2f71528f78debeb408dcc8c0fde804dea
#   Stored in directory: /Users/yangjiaochen/Library/Caches/pip/wheels/45/83/1e/3db22c5e1941c10e41c4f5cdf829b0a358146d4d0733d4a105
# Successfully built jax
# Installing collected packages: tensorboard-plugin-wit, libclang, flatbuffers, termcolor, tensorflow-io-gcs-filesystem, tensorflow-estimator, tensorboard-data-server, rsa, protobuf, oauthlib, numpy, keras, grpcio, google-pasta, gast, cachetools, astunparse, absl-py, requests-oauthlib, opt-einsum, ml-dtypes, google-auth, jax, google-auth-oauthlib, tensorboard, tensorflow
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.23.5
#     Uninstalling numpy-1.23.5:
#       Successfully uninstalled numpy-1.23.5
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# gensim 4.3.0 requires FuzzyTM>=0.4.0, which is not installed.
# daal4py 2021.6.0 requires daal==2021.4.0, which is not installed.
# Successfully installed absl-py-1.4.0 astunparse-1.6.3 cachetools-5.3.0 flatbuffers-23.3.3 gast-0.4.0 google-auth-2.17.3 google-auth-oauthlib-1.0.0 google-pasta-0.2.0 grpcio-1.54.0 jax-0.4.8 keras-2.12.0 libclang-16.0.0 ml-dtypes-0.1.0 numpy-1.22.4 oauthlib-3.2.2 opt-einsum-3.3.0 protobuf-4.22.3 requests-oauthlib-1.3.1 rsa-4.9 tensorboard-2.12.2 tensorboard-data-server-0.7.0 tensorboard-plugin-wit-1.8.1 tensorflow-2.12.0 tensorflow-estimator-2.12.0 tensorflow-io-gcs-filesystem-0.32.0 termcolor-2.3.0
# 2023-04-29 18:42:41.374855: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
import pandas as pd
progress = pd.read_csv('progress.csv')
progress.tail()
# Out:
#      episode_reward_max  episode_reward_min  episode_reward_mean  \
# 995          880.249973         -256.962988           279.653499
# 996          934.167804         -256.962988           272.606623
# 997          934.167804         -214.905597           289.462923
# 998          934.167804         -237.176115           304.861806
# 999          934.167804         -237.176115           254.885037
#
#      episode_len_mean  episodes_this_iter policy_reward_mean custom_metrics  \
# 995           2361.10                  28                 {}             {}
# 996           2304.19                  26                 {}             {}
# 997           2251.16                  28                 {}             {}
# 998           2231.01                  27                 {}             {}
# 999           2113.54                  31                 {}             {}
#
#      num_metric_batches_dropped  \
# 995                           0
# 996                           0
# 997                           0
# 998                           0
# 999                           0
#
#                                                   info  timesteps_this_iter  \
# 995  {'cur_lr': 4.999999873689376e-05, 'total_loss'...                60000
# 996  {'cur_lr': 4.999999873689376e-05, 'total_loss'...                60000
# 997  {'cur_lr': 4.999999873689376e-05, 'total_loss'...                60000
# 998  {'cur_lr': 4.999999873689376e-05, 'total_loss'...                60000
# 999  {'cur_lr': 4.999999873689376e-05, 'total_loss'...                60000
#
#      ...  training_iteration  time_this_iter_s   time_total_s      pid  \
# 995  ...                 996        162.212258  153051.018745  1067001
# 996  ...                 997        159.944548  153210.963294  1067001
# 997  ...                 998        159.949601  153370.912894  1067001
# 998  ...                 999        161.055100  153531.967994  1067001
# 999  ...                1000        163.080342  153695.048337  1067001
#
#                 hostname         node_ip  \
# 995  cee-seb218-peetalx1  128.61.129.242
# 996  cee-seb218-peetalx1  128.61.129.242
# 997  cee-seb218-peetalx1  128.61.129.242
# 998  cee-seb218-peetalx1  128.61.129.242
# 999  cee-seb218-peetalx1  128.61.129.242
#
#                                                 config  time_since_restore  \
# 995  {'monitor': False, 'log_level': 'INFO', 'callb...       153051.018745
# 996  {'monitor': False, 'log_level': 'INFO', 'callb...       153210.963294
# 997  {'monitor': False, 'log_level': 'INFO', 'callb...       153370.912894
# 998  {'monitor': False, 'log_level': 'INFO', 'callb...       153531.967994
# 999  {'monitor': False, 'log_level': 'INFO', 'callb...       153695.048337
#
#      timesteps_since_restore  iterations_since_restore
# 995                 59760000                       996
# 996                 59820000                       997
# 997                 59880000                       998
# 998                 59940000                       999
# 999                 60000000                      1000
#
# [5 rows x 26 columns]

# %%
# %load_ext tensorboard
tensorboard --logdir ~/ray_results/experiment_dir/result/directory
# Out:
#       <iframe id="tensorboard-frame-e81dbc0982237003" width="100%" height="800" frameborder="0">
#       </iframe>
#       <script>
#         (function() {
#           const frame = document.getElementById("tensorboard-frame-e81dbc0982237003");
#           const url = new URL("/", window.location);
#           const port = 6006;
#           if (port) {
#             url.port = port;
#           }
#           frame.src = url;
#         })();
#       </script>
